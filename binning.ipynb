# %%
import pandas as pd
import numpy as np

data = {
    "name": ["Rahul", "Priya", "Aman", "Sneha", "Rohan", "Anjali", "Vikas", "Neha", "Arjun", "Kavya"],

    "age": [18, 19, 20, 18, 17, 16, 15, 24, 25, 26],

    "height": [170, 160, 175, 162, 168, 158, 172, 165, 180, 163],

    "weight": [65, 52, 55, 70, 60, 48, 68, 57, 75, 50],

    "grade": ["A", "B", "B", "A", "B", "A", "C", "B", "A", "B"]
}

df = pd.DataFrame(data)

original = df.copy()

original["Age_Category"] = pd.cut(
                                    original["age"],
                                    bins=[0,18,30],
                                    labels =["Teenager","Adult"]
                                )


print(original)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       8     "weight": [65, 52, 55, 70],
#       9     "grade": ["A", "B", "B", "A"]
#      10 }
#      11
# ---> 12 df = pd.DataFrame(data)
#      13
#      14 original = df.copy()
#      15
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# ...
