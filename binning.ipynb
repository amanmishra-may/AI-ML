# %%
import pandas as pd
import numpy as np

data = {
    "name": ["Rahul", "Priya", "Aman", "Sneha", "Rohan", "Anjali", "Vikas", "Neha", "Arjun", "Kavya"],

    "age": [18, 19, 20, 18, 17, 16, 15, 24, 25, 26],

    "height": [170, 160, 175, 162, 168, 158, 172, 165, 180, 163],

    "weight": [65, 52, 55, 70, 60, 48, 68, 57, 75, 50],

    "grade": ["A", "B", "B", "A", "B", "A", "C", "B", "A", "B"]
}

df = pd.DataFrame(data)

original = df.copy()

original["Age_Category"] = pd.cut(
                                    original["age"],
                                    bins=[0,18,30],
                                    labels =["Teenager","Adult"]
                                )


print(original)
# Out:
#      name  age  height  weight grade Age_Category
# 0   Rahul   18     170      65     A     Teenager
# 1   Priya   19     160      52     B        Adult
# 2    Aman   20     175      55     B        Adult
# 3   Sneha   18     162      70     A     Teenager
# 4   Rohan   17     168      60     B     Teenager
# 5  Anjali   16     158      48     A     Teenager
# 6   Vikas   15     172      68     C     Teenager
# 7    Neha   24     165      57     B        Adult
# 8   Arjun   25     180      75     A        Adult
# 9   Kavya   26     163      50     B        Adult
